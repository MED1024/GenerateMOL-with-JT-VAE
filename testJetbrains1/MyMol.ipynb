# %% [markdown]
# # Visualization of the resulting molecules

# %% [markdown]
# ## Result of the model JT-VAE

# %%
from IPython.display import Image
Image(url= "result.jpg")
# Out:
# <img src="result.jpg"/>

# %% [markdown]
# ## Visualization

# %%
from rdkit import Chem

# %%
m1 = Chem.MolFromSmiles('COc1ncc(C(=O)NCc2cccc(Br)c2)c(C)n1')
m1

# %%
m2 = Chem.MolFromSmiles('Cc1noc(CC(=O)N2CCOCC[C@@H]2C(C)C)n1')
m2

# %%
m3 = Chem.MolFromSmiles('CC(=O)N1C=C(CC(=O)N[C@@H]2CCc3ccccc3C2)CC1')
m3

# %%
m4 = Chem.MolFromSmiles('CNC(=O)C1=CN(Cc2ccoc2C)c2ccccc2S1')
m4

# %%
m5 = Chem.MolFromSmiles('Cc1[nH]ncc1NC(=O)c1cccc(OCC(N)=O)c1')
m5

# %%
m6 = Chem.MolFromSmiles('C[C@H]1C[C@H](NC(=O)Cc2ccc(N)nc2)CC[NH2+]1')
m6

# %%
m7 = Chem.MolFromSmiles('CCCN(C)[C@@H](C=O)CNc1ccc(C#N)c2c1NCCO2')
m7

# %%
m8 = Chem.MolFromSmiles('CCNS(=O)(=O)c1ccccc1C(=O)N1CCO[C@@H](C)C1')
m8

# %%
m9 = Chem.MolFromSmiles('COc1ccc(C(=O)NCc2cccc3c2OCO3)nc1')
m9

# %%
m10 = Chem.MolFromSmiles('CC(=O)N1C=C[C@@H](C(=O)Oc2cccc(C(F)F)c2)C1')
m10
